# %% [markdown]
# # Inventory Management System

# %%
import json
from random import random

# %%
def main():
    print('\n \t\t----------WELCOME -------------\n')
    print('\n1. Admin \n2. User ')
    ui=[]
    ui = [item for item in input("Enter your Selection : ").split()]
    with open('inventory.json', 'r') as inv:
        data = json.load(inv)
        ids = data['products'].keys()
        if (ui[0]=='1'):
            admin_panel()
        elif (ui[0]=='2'):
            user_panel()
        else:
            for i in ui:
                if (i not in ids):
                    print("Invalid Try again")
                    main()
        transaction(ui)

# %%
def admin_panel():
    print('\t\t----------WELCOME TO ADMIN PANEL----------')
    print('1- Add product')
    print('2- Update product')
    print('3- View product')
    print('4- Delete product')
    print('5- Logout')
    option = int(input('Enter option: ').strip())
    if option == 5:
        main()
    if option < 1 or option > 4:
        print('Invalid option')
        input('Press <enter> key to continue ...')
        return admin_panel()
    if option == 1:
        add_product()
    elif option == 2:
        update_product()
    elif option == 3:
        view_product()
    else:
        delete_product()
    return admin_panel()

# %%
def user_panel():
    pdt_ids = []
    print('\t\t----------WELCOME TO USER PANEL----------')
    print('1- View Products')
    print('2- Purchase Products')
    print('3- Logout')
    option = int(input('Enter Your Selection:').strip())
    if option == 3:
        main()
    if option < 1 or option > 2:
        print('Invalid option')
        input('Press <enter> key to continue ...')
        return user_panel()
    if option == 1:
         view_product()
    else:
        print('\nWhat you want to buy\n')
        pdt_ids = [item for item in input("Enter the Product IDs : ").split()]
        with open('inventory.json', 'r') as inv:
            data = json.load(inv)
            ids = data['products'].keys()
        transaction(pdt_ids)

    return user_panel()

# %%
def add_product():
    product_name = input('Enter product name: ').strip()
    quantity = int(input('Enter Quantity available: ').strip())
    category = input('Enter Category: ').strip()
    brand = input('Enter Brand: ').strip()
    price = float(input('Enter price: ').strip())

    if not product_name:
        print('Please fill all the fields correctly ...')
        return add_product()

    product_id = str(int(random() * 10000))
    with open('inventory.json', 'r') as inv:
        data = json.load(inv)
        data['products'][product_id] = {
            "name": product_name,
            "price": price,
            "quantity" : quantity,
            "category" : category,
            "brand" : brand
        }
        with open('inventory.json', 'w') as inv:
            json.dump(data, inv, indent=2, sort_keys=True)
           
    return admin_panel()

# %%
def view_product():
    with open('inventory.json','r') as inv:
        data=json.load(inv)
        inv.close()
        for product_id, product in data['products'].items():
            print(f"Product ID: {product_id} ",f": {product['name']}")

# %%
def update_product():
    product_id = input('Enter product id: ').strip()
    if not product_id:
        print("Please enter a valid id ...")
        return update_product()

    with open('inventory.json', 'r') as inv:
        data = json.load(inv)
        ids = data['products'].keys()
        if product_id not in ids:
            print("Please enter a valid id ...")
            return update_product()

        u_name = input('Enter updated product name: ').strip()
        u_price =input('Enter updated price: ').strip()
        u_quantity = input('Enter updated Quantity: ').strip()
        u_category = input('Enter updated category: ').strip()
        u_brand = input('Enter updated brand: ').strip()
        

        if not u_name:
            u_name = data['products'][product_id]['name']
            
        if not u_price:
            u_price = data['products'][product_id]['price']
        
        if not u_category:
            u_category = data['products'][product_id]['category']

        if not u_brand:
            u_brand = data['products'][product_id]['brand']
            
        if not u_quantity:
            u_quantity = data['products'][product_id]['quantity']
            updated_product = {
            "name": u_name,
            "price": int(u_price),
            "quantity" : int(u_quantity),
            "category" : u_category,
            "brand" : u_brand
        }

        data['products'][product_id] = updated_product

        with open('inventory.json', 'w') as inv:
            json.dump(data, inv,indent=2, sort_keys=True)
            
        return admin_panel()

# %%
def delete_product():
    product_id = input('Enter product id: ').strip()
    if not product_id:
        print("Please enter a valid id ...")
        return update_product()

    with open('inventory.json', 'r') as inv:
        data = json.load(inv)
        ids = data['products'].keys()
        if product_id not in ids:
            print("Please enter a valid id ...")
            return update_product()

        data['products'].pop(product_id)

        with open('inventory.json', 'w') as inv:
            json.dump(data, inv,indent=2, sort_keys=True)
        
            
    return admin_panel()

# %%
def transaction(pdt_ids) :
        import time
        time.ctime()
        import json
        sales = {}
        report=[]
        total=0
        with open('inventory.json','r') as j_f:
            data=json.load(j_f)
        import json
        a_file = open("inventory.json", "r")
        json_object = json.load(a_file)
        a_file.close()
            
        order={}

            
        for pdt_id in pdt_ids:
            print(f"Selected Product Name: {data['products'][pdt_id]['name']} -",f"Price : {data['products'][pdt_id]['price']}")
            order[pdt_id]=input("Enter the Quantity: ")
        
        print("\t\t----------BILLING SECTION----------")
        print("Receipt No :\n")
        print(time.ctime(),'\n')
        for x, y in order.items():
            print(f"{data['products'][x]['name']}  : {data['products'][x]['price']} *",y,"=",int(data['products'][x]['price'])*int(y))
            total+= (int(data['products'][x]['price'])*int(y))
        print("-----------------------------------")
        for p, q in order.items():
            data ['products'][p]['quantity'] = int(int(data ['products'][p]['quantity']) - int(q))
            j_f = open("inventory.json", "w+")
            json.dump(data, j_f) 
            report.append( '\n\n'+str(time.ctime())+'\n'+'Product name: '+data['products'][p]['name']+" Qty "+str(data['products'][p]['quantity'])+"\nTotal Amt: "+ str(data['products'][p]['price'])+' '+str(total))
            fdr=open('report.txt','a') 
            for i in report:
                fdr.write(i)
            fdr.close()       
        return user_panel()
        print("------------------------------------")
        print("Total =",total,"Rs")
        print("-------------------------------------")  
        with open("sales.json", "w") as outfile:
             json.dump(sales, outfile, indent=1)

# %%
main()
# Out:
#  		----------WELCOME -------------
#
#
# 1. Admin
# 2. User
# Enter your Selection : 1
# 		----------WELCOME TO ADMIN PANEL----------
# 1- Add product
# 2- Update product
# 3- View product
# 4- Delete product
# 5- Logout
# Enter option: 3
# Product ID: 1000  : Yippie
# Product ID: 1001  : soya oil
# Product ID: 1002  : crakers bar
# Product ID: 1003  : Onion
# Product ID: 1004  : tomato sos
# Product ID: 1005  : Exo bar
# Product ID: 1006  : nestle freshness coffee
# Product ID: 1007  : banana
# Product ID: 1008  : Red chilli powder
# Product ID: 1009  : Happy Happy
# Product ID: 1010  : sweet nuts
# Product ID: 1011  : Haldi powder
# Product ID: 1012  : Namkeen
# Product ID: 1013  : Bread
# Product ID: 1014  : lady finger
# Product ID: 1015  : Eggs
# Product ID: 1016  : salt and spicy
# Product ID: 1017  : Apple
# Product ID: 1018  : chocolate sos
# Product ID: 1019  : Coconut Oil
# Product ID: 1020  : mango
# Product ID: 1021  : Cheese
# Product ID: 1022  : poha
# Product ID: 1023  : Almonds nuts
# Product ID: 1024  : oreo cookie
# Product ID: 1025  : dove soap
# Product ID: 1028  : sooje
# Product ID: 1029  : paneer masala
# Product ID: 1030  : Dark chocolate
# 		----------WELCOME TO ADMIN PANEL----------
# 1- Add product
# 2- Update product
# 3- View product
# 4- Delete product
# 5- Logout
# Enter option: 4
# Enter product id: 1028
# 		----------WELCOME TO ADMIN PANEL----------
# 1- Add product
# 2- Update product
# 3- View product
# 4- Delete product
# 5- Logout
# Enter option: 3
# Product ID: 1000  : Yippie
# Product ID: 1001  : soya oil
# Product ID: 1002  : crakers bar
# Product ID: 1003  : Onion
# Product ID: 1004  : tomato sos
# Product ID: 1005  : Exo bar
# Product ID: 1006  : nestle freshness coffee
# Product ID: 1007  : banana
# Product ID: 1008  : Red chilli powder
# Product ID: 1009  : Happy Happy
# Product ID: 1010  : sweet nuts
# Product ID: 1011  : Haldi powder
# Product ID: 1012  : Namkeen
# Product ID: 1013  : Bread
# Product ID: 1014  : lady finger
# Product ID: 1015  : Eggs
# Product ID: 1016  : salt and spicy
# Product ID: 1017  : Apple
# Product ID: 1018  : chocolate sos
# Product ID: 1019  : Coconut Oil
# Product ID: 1020  : mango
# Product ID: 1021  : Cheese
# Product ID: 1022  : poha
# Product ID: 1023  : Almonds nuts
# Product ID: 1024  : oreo cookie
# Product ID: 1025  : dove soap
# Product ID: 1029  : paneer masala
# Product ID: 1030  : Dark chocolate
# 		----------WELCOME TO ADMIN PANEL----------
# 1- Add product
# 2- Update product
# 3- View product
# 4- Delete product
# 5- Logout
# Enter option: 5
#
#  		----------WELCOME -------------
#
#
# 1. Admin
# 2. User
# Enter your Selection : 2
# 		----------WELCOME TO USER PANEL----------
# 1- View Products
# 2- Purchase Products
# 3- Logout
# Enter Your Selection:1
# Product ID: 1000  : Yippie
# Product ID: 1001  : soya oil
# Product ID: 1002  : crakers bar
# Product ID: 1003  : Onion
# Product ID: 1004  : tomato sos
# Product ID: 1005  : Exo bar
# Product ID: 1006  : nestle freshness coffee
# Product ID: 1007  : banana
# Product ID: 1008  : Red chilli powder
# Product ID: 1009  : Happy Happy
# Product ID: 1010  : sweet nuts
# Product ID: 1011  : Haldi powder
# Product ID: 1012  : Namkeen
# Product ID: 1013  : Bread
# Product ID: 1014  : lady finger
# Product ID: 1015  : Eggs
# Product ID: 1016  : salt and spicy
# Product ID: 1017  : Apple
# Product ID: 1018  : chocolate sos
# Product ID: 1019  : Coconut Oil
# Product ID: 1020  : mango
# Product ID: 1021  : Cheese
# Product ID: 1022  : poha
# Product ID: 1023  : Almonds nuts
# Product ID: 1024  : oreo cookie
# Product ID: 1025  : dove soap
# Product ID: 1029  : paneer masala
# Product ID: 1030  : Dark chocolate
# 		----------WELCOME TO USER PANEL----------
# 1- View Products
# 2- Purchase Products
# 3- Logout
# Enter Your Selection:2
#
# What you want to buy
#
# Enter the Product IDs : 1023
# Selected Product Name: Almonds nuts - Price : 80
# Enter the Quantity: 3
# 		----------BILLING SECTION----------
# Receipt No :
#
# Mon Sep  6 03:46:56 2021
#
# Almonds nuts  : 80 * 3 = 240
# -----------------------------------
# 		----------WELCOME TO USER PANEL----------
# 1- View Products
# 2- Purchase Products
# 3- Logout
# Enter Your Selection:3
#
#  		----------WELCOME -------------
#
#
# 1. Admin
# 2. User
